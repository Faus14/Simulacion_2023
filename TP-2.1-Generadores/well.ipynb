# %%
from generadorWELL import WellGenerator as WellG
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import decimal
import scipy.stats as stats
from scipy.stats import chisquare

# %%
well = WellG(12345)
dataWell= []
for i in range(500):
    numero = well.random()
    # Hacer algo con el número generado
    dataWell.append(numero)

# Crear un DataFrame de Pandas a partir de la lista de datos generados
WELL_df = pd.DataFrame(dataWell, columns=['Data'])



print(WELL_df)
# Out:
#               Data
# 0     9.965299e-01
# 1     2.940845e-01
# 2     8.978571e-01
# 3     4.586268e-01
# 4     1.974966e-01
# ..             ...
# 495  7.559917e+174
# 496  1.511097e+174
# 497  4.549524e+174
# 498  2.442815e+175
# 499  1.829586e+176
#
# [500 rows x 1 columns]

# %%
plt.hist(WELL_df, bins=20, density=True)
plt.xlabel('Valor generado')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma de números pseudoaleatorios - WELL')
plt.show()
